# %%
#!pip install deepface

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img_path = 'jaimg.jpg'

# %%
img = cv2.imread(img_path)

# %%
plt.imshow(img[:, :, ::-1])

# %%
demography = DeepFace.analyze(img_path)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 3s 3s/step
# Action: age:  25%|██▌       | 1/4 [00:04<00:14,  4.74s/it]
# 1/1 [==============================] - 1s 536ms/step
# Action: gender:  50%|█████     | 2/4 [00:05<00:04,  2.33s/it]
# 1/1 [==============================] - 0s 486ms/step
# Action: race:  75%|███████▌  | 3/4 [00:05<00:01,  1.51s/it]
# 1/1 [==============================] - 0s 364ms/step
# Action: race: 100%|██████████| 4/4 [00:06<00:00,  1.58s/it]

# %%
demography
# Out:
# {'emotion': {'angry': 13.923883438110352,
#   'disgust': 0.00010513394954614341,
#   'fear': 2.34152190387249,
#   'happy': 0.010625177674228325,
#   'sad': 35.51165759563446,
#   'surprise': 0.0004066231213073479,
#   'neutral': 48.21179807186127},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 75, 'y': 59, 'w': 83, 'h': 83},
#  'age': 27,
#  'gender': 'Man',
#  'race': {'asian': 85.67677565536209,
#   'indian': 6.8307966686244805,
#   'black': 0.34281315177686833,
#   'white': 0.9125521563055702,
#   'middle eastern': 0.06573565389417456,
#   'latino hispanic': 6.171330055156953},
#  'dominant_race': 'asian'}
